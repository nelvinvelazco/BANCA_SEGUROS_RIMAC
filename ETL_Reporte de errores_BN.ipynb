# %%
import pandas as pd
from datetime import datetime
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")
import os
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df_desgravamen= pd.read_excel('C:/DATOS/reporte de errores - banco de la nacion.xlsx', sheet_name=0,
                              dtype={'CÓDIGO PRODUCTO': str, 'DESCRIPCION ERROR': str, 'IDEDET': str, 'CÓDIGO ERROR	': str})
df_desgravamen.columns = (df_desgravamen.columns.str.strip().str.upper()
                            .str.replace(r'[^A-Za-z0-9]', '_', regex=True)  # reemplazar todo lo que no sea letra/número/_ por _
)

# %%
df_desgravamen.drop(['XXX'], axis=1, inplace=True)

# %%
df_desgravamen= df_desgravamen.rename(columns={'C_DIGO_PRODUCTO':'CODIGO_PRODUCTO','C_D__CERTIFICADO_CANAL':'CODIGO_CERTIFICADO',
                                               'C_DIGO_ERROR':'CODIGO_ERROR', 'DESCRIPCI_N_ERROR':'DESCRIPCION_ERROR',
                                                'VALIDACI_N_APLICADA':'VALIDACION_APLICADA', 'VALIDACI_N_APLICADA':'VALIDACION_APLICADA',
                                                'NRO__LOTE_DEL_ERROR':'NRO_LOTE_DEL_ERROR', 'DOC__ID_':'DOC_ID',
                                                'FEC__INICIO':'FECHA_INICIO', 'FEC__FIN':'FECHA_FIN', 'L_NEA_DE_TRAMA':'LINEA_DE_TRAMA',
                                                'LINEA_TRAMA_TEXTO_COMPLETO_':'TRAMA_TEXTO_COMPLETO'})

# %%
df_desgravamen.head(3)
# Out:
#    NRO_LOTE  NRO_LOTES_ANTERIORES    FECHA_CARGA_LOTE CODIGO_PRODUCTO  \
# 0   1394344                   NaN 2026-04-28 20:31:02            3189
# 1   1394344                   NaN 2026-04-28 20:31:02            3189
# 2   1394344                   NaN 2026-04-28 20:31:02            3189
#
#                          PRODUCTO  PLAN NOMBRE_DE_PLAN     CODIGO_CERTIFICADO  \
# 0  Desgravamen Banco de la Nacion     0            NaN  C00000000000000043365
# 1  Desgravamen Banco de la Nacion     0            NaN  C00000000000000043365
# 2  Desgravamen Banco de la Nacion     0            NaN  C00000000000000043365
#
#       IDEDET TIPO_MOVIMIENTO ORIGEN_ERROR  CODIGO_ERROR  \
# 0  886701890      Renovacion  Error Canal          1056
# 1  886701890      Renovacion  Error Canal          8006
# 2  886701890      Renovacion  Error Canal           199
#
#                                    DESCRIPCION_ERROR  \
# 0  EL ALTA DEL NRO. CERTIFICADO EXTERNO: 00000000...
# 1  EL CAMPO FECINIVIGENCIA NO CORRESPONDE AL PLAN...
# 2  No se puede ejecutar la validación Fecha de fi...
#
#                                  VALIDACION_APLICADA  NRO_LOTE_DEL_ERROR  \
# 0  EL ALTA DEL NRO. CERTIFICADO EXTERNO: 00000000...                 NaN
# 1  EL CAMPO FECINIVIGENCIA NO CORRESPONDE AL PLAN...                 NaN
# 2  No se puede ejecutar la validación Fecha de fi...                 NaN
#
#    NOMBRE  APELLIDO_PATERNO  APELLIDO_MATERNO  FECHA_NACIMIENTO  TIPO_DOC__ID  \
# 0     NaN               NaN               NaN               NaN           NaN
# 1     NaN               NaN               NaN               NaN           NaN
# 2     NaN               NaN               NaN               NaN           NaN
#
#    DOC_ID FECHA_INICIO  FECHA_FIN MONEDA  SUMA_ASEGURADA  TASA  \
# 0     NaN   2026-04-04 2026-05-03    SOL        11849.08     0
# 1     NaN   2026-04-04 2026-05-03    SOL        11849.08     0
# 2     NaN   2026-04-04 2026-05-03    SOL        11849.08     0
#
#    TASA_CON_RECARGO  PRIMABRUTACAN  PRIMANETACAN  PLACA  MOTOR  \
# 0                 0            8.9           8.9    NaN    NaN
# 1                 0            8.9           8.9    NaN    NaN
# 2                 0            8.9           8.9    NaN    NaN
#
#                          NOMBRE_ARCHIVO  LINEA_DE_TRAMA  \
# 0  20100030595_0144001_20260428_008.TXT           13730
# 1  20100030595_0144001_20260428_008.TXT           13730
# 2  20100030595_0144001_20260428_008.TXT           13730
#
#                                 TRAMA_TEXTO_COMPLETO
# 0  0000035729000003572901440010000000000000004336...
# 1  0000035729000003572901440010000000000000004336...
# 2  0000035729000003572901440010000000000000004336...

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   NRO_LOTE                     300 non-null    int64
#  1   NRO_LOTES_ANTERIORES         0 non-null      float64
#  2   FECHA_CARGA_LOTE             300 non-null    datetime64[us]
#  3   C_DIGO_PRODUCTO              300 non-null    str
#  4   PRODUCTO                     300 non-null    str
#  5   PLAN                         300 non-null    int64
#  6   NOMBRE_DE_PLAN               3 non-null      str
#  7   C_D__CERTIFICADO_CANAL       300 non-null    str
#  8   IDEDET                       300 non-null    str
#  9   TIPO_MOVIMIENTO              300 non-null    str
#  10  ORIGEN_ERROR                 300 non-null    str
#  11  C_DIGO_ERROR                 300 non-null    int64
#  12  DESCRIPCI_N_ERROR            300 non-null    str
#  13  VALIDACI_N_APLICADA          300 non-null    str
#  14  NRO__LOTE_DEL_ERROR          0 non-null      float64
#  15  NOMBRE                       0 non-null      float64
#  16  APELLIDO_PATERNO             0 non-null      float64
#  17  APELLIDO_MATERNO             0 non-null      float64
#  18  FECHA_NACIMIENTO             0 non-null      float64
#  19  TIPO_DOC__ID                 0 non-null      float64
#  20  DOC__ID_                     0 non-null      float64
#  21  FEC__INICIO                  300 non-null    datetime64[us]
#  22  FEC__FIN                     300 non-null    datetime64[us]
#  23  MONEDA                       300 non-null    str
#  24  SUMA_ASEGURADA               300 non-null    float64
#  25  TASA                         300 non-null    int64
#  26  TASA_CON_RECARGO             300 non-null    int64
#  27  PRIMABRUTACAN                300 non-null    float64
#  28  PRIMANETACAN                 300 non-null    float64
#  29  PLACA                        0 non-null      float64
#  30  MOTOR                        0 non-null      float64
#  31  NOMBRE_ARCHIVO               300 non-null    str
#  32  L_NEA_DE_TRAMA               300 non-null    int64
#  33  LINEA_TRAMA_TEXTO_COMPLETO_  300 non-null    str
# dtypes: datetime64[us](3), float64(13), int64(6), str(12)
# memory usage: 79.8 KB
