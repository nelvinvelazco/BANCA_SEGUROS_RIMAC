# %%
import re
import os
from datetime import datetime

# %%
trama_vieja= "C:/DATOS/trama antigua BN.txt"
trama_nueva= "C:/DATOS/trama nueva BN.txt"
trama_final = "C:/DATOS/trama_final.txt"

# %%
with open(trama_vieja, "r", encoding="latin-1") as trv, \
     open(trama_nueva, "r", encoding="latin-1") as trn, \
     open(trama_final, "w", encoding="latin-1") as trfin:

    for linea_trv, linea_trn in zip(trv, trn):
        linea_final = linea_trn[:4040]
        prima_str= linea_trv[19:34]
        suma_aseg_str= linea_trv[118:133]
        linea_final= linea_final[:3655]+suma_aseg_str + prima_str + prima_str + linea_final[3700:]
        trfin.write(linea_final)
